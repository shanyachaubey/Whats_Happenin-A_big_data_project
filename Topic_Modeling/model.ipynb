# %%
#LDA variable its taking as new_labeled_data

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import json
import numpy as np
import joblib

# Load Existing and New Labeled Data
with open('existing_dataset.json', 'r') as f:
    existing_data = json.load(f)

new_labeled_data = []



# Combine Datasets
combined_data = existing_data + new_labeled_data

# Preprocessing
texts = [sample['title'] + ' ' + sample['summary'] for sample in combined_data]

# Vectorize the text data
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(texts)


# Topic Modeling with LDA
lda = LatentDirichletAllocation(n_components=10, random_state=42)  # Assuming 10 categories
lda.fit(X)

# Prediction
predicted_categories = lda.transform(X)

# Print predicted categories for data
print("Predicted categories:")
for idx, (title, summary, pred_category) in enumerate(zip([sample['title'] for sample in combined_data], 
                                                          [sample['summary'] for sample in combined_data], 
                                                          predicted_categories)):
    category_idx = np.argmax(pred_category)
    #print(f"Title: {title}\nSummary: {summary}\nPredicted Category Index: {category_idx}\n")



#This is just for clarity 
category_names = {
    0: "Technology",
    1: "Environment/Nature",
    2: "Social Issues",
    3: "Infrastructure",
    4: "Entertainment",
    5: "Health",
    6: "Economy",
    7: "Science",
    8: "Education",
    9: "Government"
}

# Print predicted categories for data
print("Predicted categories:")
for title, summary, pred_category in zip([sample['title'] for sample in combined_data], 
                                         [sample['summary'] for sample in combined_data], 
                                         predicted_categories):
    category_idx = np.argmax(pred_category)
    category_name = category_names[category_idx]
    #print(f"Title: {title}\nSummary: {summary}\nPredicted Category: {category_name}\n")

    
    # Print predicted categories for data in the index
print("Predicted categories:")
for idx, (title, summary, pred_category) in enumerate(zip([sample['title'] for sample in combined_data], 
                                                          [sample['summary'] for sample in combined_data], 
                                                          predicted_categories)):
    category_idx = np.argmax(pred_category)
    category_name = category_names[category_idx]
    print(f"{idx + 1}: {category_name}")

    




#PERCENTAGE OF LDA
# Calculate the percentage of each category
category_counts = {category_names[i]: 0 for i in range(len(category_names))}
total_predictions = len(predicted_categories)

for pred_category in predicted_categories:
    category_idx = np.argmax(pred_category)
    category_name = category_names[category_idx]
    category_counts[category_name] += 1

# Print percentage of each category
print("Percentage of each category:")
for category, count in category_counts.items():
    percentage = (count / total_predictions) * 100
    print(f"{category}: {percentage:.2f}%")

joblib.dump(lda, 'model.pkl')    
import joblib

joblib.dump(lda, 'lda_model.jl')
# Out:
# Predicted categories:
# Predicted categories:
# Predicted categories:
# 1: Economy
# 2: Science
# 3: Entertainment
# 4: Health
# 5: Social Issues
# 6: Social Issues
# 7: Education
# 8: Environment/Nature
# 9: Education
# 10: Government
# 11: Government
# 12: Entertainment
# 13: Science
# 14: Government
# 15: Technology
# 16: Government
# 17: Environment/Nature
# 18: Education
# 19: Education
# 20: Infrastructure
# 21: Economy
# 22: Social Issues
# 23: Environment/Nature
# 24: Environment/Nature
# 25: Environment/Nature
# 26: Social Issues
# 27: Environment/Nature
# 28: Economy
# 29: Economy
# 30: Science
# 31: Environment/Nature
# 32: Entertainment
# 33: Science
# 34: Health
# 35: Health
# 36: Health
# 37: Entertainment
# 38: Economy
# 39: Health
# 40: Economy
# 41: Government
# 42: Government
# 43: Government
# 44: Government
# 45: Health
# 46: Environment/Nature
# 47: Health
# 48: Education
# 49: Social Issues
# 50: Government
# 51: Health
# 52: Education
# 53: Environment/Nature
# 54: Entertainment
# 55: Science
# 56: Education
# 57: Economy
# 58: Social Issues
# 59: Environment/Nature
# 60: Health
# 61: Science
# 62: Health
# 63: Environment/Nature
# 64: Environment/Nature
# 65: Social Issues
# 66: Social Issues
# 67: Social Issues
# 68: Government
# 69: Environment/Nature
# 70: Environment/Nature
# 71: Environment/Nature
# 72: Social Issues
# 73: Infrastructure
# 74: Health
# 75: Economy
# 76: Economy
# 77: Science
# 78: Economy
# 79: Science
# 80: Entertainment
# 81: Health
# 82: Social Issues
# 83: Economy
# 84: Infrastructure
# 85: Science
# 86: Infrastructure
# 87: Environment/Nature
# 88: Entertainment
# 89: Environment/Nature
# 90: Government
# 91: Government
# 92: Entertainment
# 93: Education
# 94: Environment/Nature
# 95: Infrastructure
# 96: Government
# 97: Economy
# 98: Science
# 99: Health
# 100: Environment/Nature
# 101: Technology
# 102: Economy
# 103: Health
# 104: Science
# 105: Environment/Nature
# 106: Health
# 107: Health
# 108: Economy
# 109: Economy
# 110: Health
# 111: Entertainment
# 112: Entertainment
# 113: Entertainment
# 114: Health
# 115: Infrastructure
# 116: Health
# 117: Government
# 118: Entertainment
# 119: Science
# 120: Health
# 121: Government
# 122: Environment/Nature
# 123: Entertainment
# 124: Entertainment
# 125: Science
# 126: Infrastructure
# 127: Environment/Nature
# 128: Health
# 129: Health
# 130: Health
# 131: Environment/Nature
# 132: Health
# 133: Environment/Nature
# 134: Social Issues
# 135: Government
# 136: Science
# 137: Entertainment
# 138: Environment/Nature
# 139: Health
# 140: Science
# 141: Technology
# 142: Science
# 143: Infrastructure
# 144: Social Issues
# 145: Science
# 146: Environment/Nature
# 147: Infrastructure
# 148: Economy
# 149: Economy
# 150: Health
# 151: Social Issues
# 152: Environment/Nature
# 153: Social Issues
# 154: Health
# 155: Entertainment
# 156: Social Issues
# 157: Entertainment
# 158: Health
# 159: Health
# 160: Health
# 161: Science
# 162: Economy
# 163: Economy
# 164: Environment/Nature
# 165: Science
# 166: Government
# 167: Infrastructure
# 168: Science
# 169: Infrastructure
# 170: Science
# 171: Science
# 172: Environment/Nature
# 173: Social Issues
# 174: Science
# 175: Science
# 176: Infrastructure
# 177: Economy
# 178: Government
# 179: Social Issues
# 180: Social Issues
# 181: Infrastructure
# 182: Social Issues
# 183: Government
# 184: Social Issues
# 185: Social Issues
# 186: Social Issues
# 187: Infrastructure
# 188: Infrastructure
# 189: Social Issues
# 190: Health
# 191: Government
# 192: Infrastructure
# 193: Social Issues
# 194: Social Issues
# 195: Social Issues
# 196: Government
# 197: Infrastructure
# 198: Social Issues
# 199: Social Issues
# 200: Social Issues
# 201: Social Issues
# Percentage of each category:
# Technology: 1.49%
# Environment/Nature: 14.43%
# Social Issues: 15.42%
# Infrastructure: 8.46%
# Entertainment: 8.46%
# Health: 15.42%
# Economy: 9.95%
# Science: 11.94%
# Education: 3.98%
# Government: 10.45%
# ['lda_model.jl']
